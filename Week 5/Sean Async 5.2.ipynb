# %% [markdown]
# # Async 5.2.3

# %%
import pandas as pd
import seaborn as sns

# %%
titanic_df = sns.load_dataset("titanic")

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.pivot_table(values='survived', index='class')
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
grouped = titanic_df.groupby(titanic_df['class'])
grouped.count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %%
grouped[['survived']].mean()
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 grouped['First'].apply(lambda x:type(x))
#
# File ~/Documents/University_of_denver/comp_4447_tools_1/my_venv/tools_venv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
#    1767     raise ValueError(
#    1768         "Cannot subset columns with a tuple with more than one element. "
#    1769         "Use a list instead."
#    1770     )
# -> 1771 return super().__getitem__(key)
#
# File ~/Documents/University_of_denver/comp_4447_tools_1/my_venv/tools_venv/lib/python3.10/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
# ...
